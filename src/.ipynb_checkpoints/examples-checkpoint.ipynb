# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import math
import sys
from skimage.filters import threshold_otsu
from skimage.morphology import disk
from skimage.morphology import dilation
from PIL import Image
import pytesseract
import os
from resturant_menu import resturant_menu_expert

# %%
resturant_menu_expert('../img/menu2.jpg' ,4)
# Out:
# [['VEG SAMOSA', 8, 37, 172, 18, 'veg samosa']]

# %%
resturant_menu_expert('../img/menu2.jpg' ,4)
# Out:
# [['VEG PAKORA', 8, 21, 173, 18, 'veg pakora']]

# %%
resturant_menu_expert('../img/hand.jpg' ,4)
# Out:
# [['Rzza', 86, 331, 561, 202, 'pizza'], ['Mople', 155, 60, 304, 222, 'apple'], ['', 537, 616, 22, 6, None]]

# %%
resturant_menu_expert('../img/hand1.jpg' ,4)
# Out:
# [['APPIE', 178, 51, 326, 146, 'apple'], ['PIZZA', 135, 305, 345, 140, 'pizza'], ['MAGarE', 83, 505, 404, 126, 'maggie']]

# %%
orig_img = cv2.imread('../img/hand_rot.jpg' ,0)
plt.figure(figsize=(15,15))
plt.imshow(orig_img ,cmap='gray')

# %%
resturant_menu_expert('../img/hand_rot.jpg' ,4)
# Out:
# [['APPIE', 348, 189, 326, 146, 'apple'], ['PIZZA', 305, 443, 345, 140, 'pizza'], ['MAGGIE', 253, 642, 405, 127, 'maggie']]
